# %% [markdown]
# # Lunch & Learn Session: Stock Price prediction
#
# ---------------------------------------------------------------------------------------------------------------------
# ### Referance
# - Data : Kaggle DJIA 30 Stock Time Series (https://www.kaggle.com/szrlee/stock-time-series-20050101-to-20171231)
# - Notenooks referred :
#  https://www.kaggle.com/thebrownviking20/everything-you-can-do-with-a-time-series#data
#  https://www.kaggle.com/kashnitsky/topic-9-part-1-time-series-analysis-in-python

# %% [markdown]
# ### Motivation
# ![feyman1.png](attachment:feyman1.png)

# %%
#Importing Libraries
import os
import sys
import glob
import pandas as pd
import numpy as np
import datetime
from datetime import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# Above is a special style template for matplotlib, highly useful for visualizing time series data

# %matplotlib inline
from pylab import rcParams
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
import math
from sklearn.metrics import mean_squared_error
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data
# - Data being used:-
# - Google Stocks Data
# - Humidity in different world cities
# - Microsoft Stocks Data
# - Pressure in different world cities

# %%
import glob, os
os.chdir(sys.path[0]+"/stock-time-series-20050101-to-20171231")
IBM_PATH=None
for file in glob.glob("*.csv"):
    if 'GOOGL' in file:
        print(file)
# Out:
# GOOGL_2006-01-01_to_2018-01-01.csv

# %%
import glob, os
os.chdir(sys.path[0]+"/stock-time-series-20050101-to-20171231")
IBM_PATH=None
for file in glob.glob("*.csv"):
    if 'IBM' in file:
        IBM_PATH = file
        print(IBM_PATH)
#         print('Stock Prices for', file.split('_')[0], 'during' , file.split('_')[1], 'to', file.split('_')[3])
    
# Lets start analyzing big tech companies stock market data
ibm = pd.read_csv(IBM_PATH, index_col=0)
ibm.head()
# Out:
# IBM_2006-01-01_to_2018-01-01.csv
#              Open   High    Low  Close    Volume Name
# Date
# 2006-01-03  82.45  82.55  80.81  82.06  11715200  IBM
# 2006-01-04  82.20  82.50  81.33  81.95   9840600  IBM
# 2006-01-05  81.40  82.90  81.00  82.50   7213500  IBM
# 2006-01-06  83.95  85.03  83.41  84.95   8197400  IBM
# 2006-01-09  84.10  84.25  83.38  83.73   6858200  IBM

# %%
os.chdir(sys.path[0]+'/historical-hourly-weather-data')
for file in glob.glob("*.csv"):
    print(file)
# Out:
# weather_description.csv
# humidity.csv
# wind_direction.csv
# temperature.csv
# pressure.csv
# city_attributes.csv
# wind_speed.csv

# %%
humidity = pd.read_csv('../historical-hourly-weather-data/humidity.csv',index_col='datetime',parse_dates=['datetime'])
weather_description = pd.read_csv('../historical-hourly-weather-data/weather_description.csv',index_col='datetime',parse_dates=['datetime'])
wind_direction = pd.read_csv('../historical-hourly-weather-data/wind_direction.csv',index_col='datetime',parse_dates=['datetime'])
temperature = pd.read_csv('../historical-hourly-weather-data/temperature.csv',index_col='datetime',parse_dates=['datetime'])
pressure = pd.read_csv('../historical-hourly-weather-data/pressure.csv',index_col='datetime',parse_dates=['datetime'])
wind_speed = pd.read_csv('../historical-hourly-weather-data/wind_speed.csv',index_col='datetime',parse_dates=['datetime'])
print(humidity.shape)
humidity.tail()
# Out:
# (45253, 36)
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2017-11-29 20:00:00        NaN      81.0            NaN     93.0         24.0
# 2017-11-29 21:00:00        NaN      71.0            NaN     87.0         21.0
# 2017-11-29 22:00:00        NaN      71.0            NaN     93.0         23.0
# 2017-11-29 23:00:00        NaN      71.0            NaN     87.0         14.0
# 2017-11-30 00:00:00        NaN      76.0            NaN     75.0         56.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2017-11-29 20:00:00       72.0       18.0     68.0         37.0    18.0  ...
# 2017-11-29 21:00:00       72.0       18.0     73.0         34.0    12.0  ...
# 2017-11-29 22:00:00       68.0       17.0     60.0         32.0    15.0  ...
# 2017-11-29 23:00:00       63.0       17.0     33.0         30.0    28.0  ...
# 2017-11-30 00:00:00       72.0       17.0     23.0         34.0    31.0  ...
#
#                      Philadelphia  New York  Montreal  Boston  Beersheba  \
# datetime
# 2017-11-29 20:00:00          27.0       NaN      64.0    37.0        NaN
# 2017-11-29 21:00:00          29.0       NaN      59.0    74.0        NaN
# 2017-11-29 22:00:00          31.0       NaN      66.0    74.0        NaN
# 2017-11-29 23:00:00          26.0       NaN      58.0    56.0        NaN
# 2017-11-30 00:00:00          32.0       NaN      58.0    56.0        NaN
#
#                      Tel Aviv District  Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2017-11-29 20:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 21:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 22:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-29 23:00:00                NaN    NaN    NaN        NaN        NaN
# 2017-11-30 00:00:00                NaN    NaN    NaN        NaN        NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ##  Data Quality

# %%
ibm[ibm.Open.isna()]
# Out:
#             Open    High  Low   Close   Volume Name
# Date
# 2017-07-31   NaN  144.93  NaN  144.67  4355718  IBM

# %%
# %Missing data
round(humidity.isna().sum()/len(humidity)*100, 2).sort_values(ascending=False)
# Out:
# Vancouver            4.04
# Denver               4.00
# Montreal             3.75
# New York             3.59
# Phoenix              2.89
# Saint Louis          2.85
# Tel Aviv District    2.46
# Chicago              2.45
# Miami                2.40
# Eilat                2.14
# San Francisco        2.08
# Jerusalem            2.00
# Detroit              1.90
# Beersheba            1.90
# Las Vegas            1.86
# Haifa                1.81
# Nahariyya            1.81
# Toronto              1.61
# Albuquerque          1.57
# Indianapolis         1.54
# Philadelphia         1.38
# Charlotte            1.30
# Nashville            1.25
# San Antonio          1.25
# Pittsburgh           1.15
# Kansas City          1.13
# Minneapolis          1.13
# Boston               0.99
# Portland             0.99
# Atlanta              0.93
# San Diego            0.76
# Dallas               0.70
# Seattle              0.64
# Jacksonville         0.46
# Los Angeles          0.34
# Houston              0.27
# dtype: float64

# %%
humidity = humidity.iloc[1:]
humidity = humidity.fillna(method='ffill')
print(humidity.shape)
humidity.head()
# Out:
# (45252, 36)
#                      Vancouver  Portland  San Francisco  Seattle  Los Angeles  \
# datetime
# 2012-10-01 13:00:00       76.0      81.0           88.0     81.0         88.0
# 2012-10-01 14:00:00       76.0      80.0           87.0     80.0         88.0
# 2012-10-01 15:00:00       76.0      80.0           86.0     80.0         88.0
# 2012-10-01 16:00:00       77.0      80.0           85.0     79.0         88.0
# 2012-10-01 17:00:00       78.0      79.0           84.0     79.0         88.0
#
#                      San Diego  Las Vegas  Phoenix  Albuquerque  Denver  ...  \
# datetime                                                                 ...
# 2012-10-01 13:00:00       82.0       22.0     23.0         50.0    62.0  ...
# 2012-10-01 14:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 15:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 16:00:00       81.0       21.0     23.0         49.0    62.0  ...
# 2012-10-01 17:00:00       80.0       21.0     24.0         49.0    63.0  ...
#
#                      Philadelphia  New York  Montreal  Boston  Beersheba  \
# datetime
# 2012-10-01 13:00:00          71.0      58.0      93.0    68.0       50.0
# 2012-10-01 14:00:00          70.0      57.0      91.0    68.0       51.0
# 2012-10-01 15:00:00          70.0      57.0      87.0    68.0       51.0
# 2012-10-01 16:00:00          69.0      57.0      84.0    68.0       52.0
# 2012-10-01 17:00:00          69.0      57.0      80.0    68.0       54.0
#
#                      Tel Aviv District  Eilat  Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01 13:00:00               63.0   22.0   51.0       51.0       50.0
# 2012-10-01 14:00:00               62.0   22.0   51.0       51.0       50.0
# 2012-10-01 15:00:00               62.0   22.0   51.0       51.0       50.0
# 2012-10-01 16:00:00               62.0   22.0   51.0       51.0       50.0
# 2012-10-01 17:00:00               62.0   23.0   51.0       51.0       50.0
#
# [5 rows x 36 columns]

# %% [markdown]
# # Some useful methods for any timeseries data

# %%
# Visualizing humidity data for New York City
humidity['New York'].asfreq('M').plot(figsize=(20,8))
plt.title('Humidity in New York City (Monthly Frequency)')
plt.show()

# %%
ibm['2015':].plot(subplots=True, figsize=(20,15))
plt.title('IBM stock attributes from Jan,2015 to Dec,2017')
# plt.savefig('stocks.png')
plt.show()

# %% [markdown]
# ### Shifting and lags

# %%
humidity['New York'].asfreq('M').plot(figsize=(20,10),legend=True)
shifted = humidity['New York'].asfreq('M').shift(2).plot(legend=True)
shifted.legend(['New York','New York lagged'])
plt.show()

# %% [markdown]
# ## Resampling
# - Upsampling - Time series is resampled from low frequency to high frequency(Monthly to daily frequency). It involves
#   filling or interpolating missing data
#
# - Downsampling - Time series is resampled from high frequency to low frequency(Weekly to monthly frequency). It
#   involves aggregation of existing data.

# %%
down_humidity = humidity.resample('2D').mean()
print(down_humidity.shape)
down_humidity.head()
# Out:
# (944, 36)
#             Vancouver   Portland  San Francisco    Seattle  Los Angeles  \
# datetime
# 2012-10-01  77.657143  69.885714      71.314286  69.200000    72.171429
# 2012-10-03  60.583333  58.687500      53.625000  53.270833    55.750000
# 2012-10-05  43.145833  40.250000      71.604167  48.958333    72.645833
# 2012-10-07  53.270833  37.125000      71.812500  50.562500    73.916667
# 2012-10-09  69.375000  59.083333      74.354167  64.854167    73.312500
#
#             San Diego  Las Vegas    Phoenix  Albuquerque     Denver  ...  \
# datetime                                                             ...
# 2012-10-01  70.285714  17.600000  23.714286    42.542857  62.857143  ...
# 2012-10-03  67.666667  15.312500  18.916667    27.541667  26.041667  ...
# 2012-10-05  71.395833  16.645833  26.791667    19.416667  57.541667  ...
# 2012-10-07  72.625000  18.604167  25.604167    41.041667  76.687500  ...
# 2012-10-09  67.020833  18.833333  33.375000    29.562500  31.958333  ...
#
#             Philadelphia   New York   Montreal     Boston  Beersheba  \
# datetime
# 2012-10-01     58.828571  52.314286  56.028571  68.514286  67.228571
# 2012-10-03     83.916667  81.770833  93.666667  85.395833  71.500000
# 2012-10-05     76.833333  82.041667  91.729167  71.020833  65.291667
# 2012-10-07     66.604167  64.354167  76.145833  74.729167  61.791667
# 2012-10-09     74.916667  73.312500  78.916667  82.020833  62.708333
#
#             Tel Aviv District      Eilat      Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01          67.571429  30.457143  52.714286  52.714286  51.885714
# 2012-10-03          70.916667  48.312500  70.312500  70.500000  62.833333
# 2012-10-05          65.187500  47.479167  67.750000  67.750000  65.875000
# 2012-10-07          63.625000  39.395833  64.666667  64.666667  61.437500
# 2012-10-09          68.000000  41.166667  62.875000  62.875000  61.500000
#
# [5 rows x 36 columns]

# %%
up_humidity = down_humidity.resample('D').fillna(method='ffill')
print(up_humidity.shape)
up_humidity.head()
# Out:
# (1887, 36)
#             Vancouver   Portland  San Francisco    Seattle  Los Angeles  \
# datetime
# 2012-10-01  77.657143  69.885714      71.314286  69.200000    72.171429
# 2012-10-02  77.657143  69.885714      71.314286  69.200000    72.171429
# 2012-10-03  60.583333  58.687500      53.625000  53.270833    55.750000
# 2012-10-04  60.583333  58.687500      53.625000  53.270833    55.750000
# 2012-10-05  43.145833  40.250000      71.604167  48.958333    72.645833
#
#             San Diego  Las Vegas    Phoenix  Albuquerque     Denver  ...  \
# datetime                                                             ...
# 2012-10-01  70.285714  17.600000  23.714286    42.542857  62.857143  ...
# 2012-10-02  70.285714  17.600000  23.714286    42.542857  62.857143  ...
# 2012-10-03  67.666667  15.312500  18.916667    27.541667  26.041667  ...
# 2012-10-04  67.666667  15.312500  18.916667    27.541667  26.041667  ...
# 2012-10-05  71.395833  16.645833  26.791667    19.416667  57.541667  ...
#
#             Philadelphia   New York   Montreal     Boston  Beersheba  \
# datetime
# 2012-10-01     58.828571  52.314286  56.028571  68.514286  67.228571
# 2012-10-02     58.828571  52.314286  56.028571  68.514286  67.228571
# 2012-10-03     83.916667  81.770833  93.666667  85.395833  71.500000
# 2012-10-04     83.916667  81.770833  93.666667  85.395833  71.500000
# 2012-10-05     76.833333  82.041667  91.729167  71.020833  65.291667
#
#             Tel Aviv District      Eilat      Haifa  Nahariyya  Jerusalem
# datetime
# 2012-10-01          67.571429  30.457143  52.714286  52.714286  51.885714
# 2012-10-02          67.571429  30.457143  52.714286  52.714286  51.885714
# 2012-10-03          70.916667  48.312500  70.312500  70.500000  62.833333
# 2012-10-04          70.916667  48.312500  70.312500  70.500000  62.833333
# 2012-10-05          65.187500  47.479167  67.750000  67.750000  65.875000
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Percent Change

# %%
# ibm_df.High.plot(figsize=(20,10))
ibm['change'] = ibm.High.div(ibm.High.shift(1))
ibm['change'].plot(figsize=(20,10))
# google['Change'].plot(figsize=(20,8))

# %% [markdown]
# ## Returns

# %%
ibm.High.pct_change().mul(100).plot(figsize=(20,10))

# %% [markdown]
# ## Comparing returns from top tech giants

# %%
# Google 
google = pd.read_csv('GOOGL_2006-01-01_to_2018-01-01.csv', index_col=0)
google.High.div(google.High.iloc[0]).mul(100).plot(figsize=(20,10))

# Microsoft
msft = pd.read_csv('MSFT_2006-01-01_to_2018-01-01.csv', index_col=0)
msft.High.div(msft.High.iloc[0]).mul(100).plot(figsize=(20,10))

#IBM
ibm.High.div(ibm.High.iloc[0]).mul(100).plot(figsize=(20,10))

#Amazon
amazon = pd.read_csv('AMZN_2006-01-01_to_2018-01-01.csv', index_col=0)
amazon.High.div(amazon.High.iloc[0]).mul(100).plot(figsize=(20,10))


# Apple
apple = pd.read_csv('AAPL_2006-01-01_to_2018-01-01.csv', index_col=0)
apple.High.div(apple.High.iloc[0]).mul(100).plot(figsize=(20,10))

plt.title('Comparing stock prices of Top tech Giants')
plt.legend(['Google', 'Microsoft', 'IBM','Amazon', 'Apple'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
all_stocks = pd.read_csv('all_stocks_2006-01-01_to_2018-01-01.csv', index_col=0)
all_stocks[['Date', 'Name', 'High']].plot(subplot=True)
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  77.76  79.35  77.24  79.11   3117200   MMM
# 2006-01-04  79.49  79.49  78.25  78.71   2558000   MMM
# 2006-01-05  78.41  78.65  77.56  77.99   2529500   MMM
# 2006-01-06  78.64  78.90  77.64  78.63   2479500   MMM
# 2006-01-09  78.50  79.83  78.46  79.02   1845600   MMM
# ...           ...    ...    ...    ...       ...   ...
# 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [93612 rows x 6 columns]

# %% [markdown]
# ## Check for Stationarity
# - A stationary time series is one whose statistical properties such as mean, variance, autocorrelation, etc. are all constant over time.
# - Stationarity is important as non-stationary series that depend on time have too many parameters to account for when modelling the time series. diff() method can easily convert a non-stationary series to a stationary series.

# %%
# Now, for decomposition...
rcParams['figure.figsize'] = 11, 9
decomposed_ibm = sm.tsa.seasonal_decompose(ibm["High"],freq=365) # The frequncy is annual
figure = decomposed_ibm.plot()
plt.show()

# %% [markdown]
# # Autocorrelation
#
# - We can calculate the correlation for time series observations with observations with previous time steps, called lags.
#
# ### Interpretation
# - If autocorrelation values are close to 0, then values between consecutive observations are not correlated with one another. Inversely, autocorrelations values close to 1 or -1 indicate that there exists strong positive or negative correlations between consecutive observations, respectively.
#
# - In order to help you asses how trustworthy these autocorrelation values are, the plot_acf() function also returns confidence intervals (represented as blue shaded regions). If an autocorrelation value goes beyond the confidence interval region, you can assume that the observed autocorrelation value is statistically significant.

# %%
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(ibm.Volume, lags=20)

# %% [markdown]
# - As all lags are either close to 1 or at least greater than the confidence interval, they are statistically significant.

# %% [markdown]
# # Partial Autocorrelation Function
#
# - A partial autocorrelation is a summary of the relationship between an observation in a time series with observations at prior time steps with the relationships of intervening observations removed.

# %%
plot_pacf(ibm.High,lags=50)
plt.show()

# %% [markdown]
# #  Time series decomposition and Random walks
# ### Trends, seasonality and noise
# - These are the components of a time series
#
# - Trend - Consistent upwards or downwards slope of a time series
# - Seasonality - Clear periodic pattern of a time series(like sine funtion)
# - Noise - Outliers or missing values

# %% [markdown]
# # Modeling
#
#
# ### AR models
# An autoregressive (AR) model is a representation of a type of random process; as such, it is used to describe certain time-varying processes in nature, economics, etc. The autoregressive model specifies that the output variable depends linearly on its own previous values and on a stochastic term (an imperfectly predictable term); thus the model is in the form of a stochastic difference equation.
#
# - AR(1) model:
#   Rt = μ + ϕRt-1 + εt
#
# As RHS has only one lagged value(Rt-1)this is called AR model of order 1 where μ is mean and ε is noise at time t
# If ϕ = 1, it is random walk. Else if ϕ = 0, it is white noise. Else if -1 < ϕ < 1, it is stationary. If ϕ is -ve, there is men reversion. If ϕ is +ve, there is momentum.
#
# - AR(2) model: Rt = μ + ϕ1Rt-1 + ϕ2Rt-2 + εt
#
# - AR(3) model: Rt = μ + ϕ1Rt-1 + ϕ2Rt-2 + ϕ3Rt-3 + εt

# %%
# AR(1) MA(1) model:AR parameter = +0.9
rcParams['figure.figsize'] = 16, 12
plt.subplot(4,1,1)
ar1 = np.array([1, -0.9]) # We choose -0.9 as AR parameter is +0.9
ma1 = np.array([1])
AR1 = ArmaProcess(ar1, ma1)
sim1 = AR1.generate_sample(nsample=1000)
plt.title('AR(1) model: AR parameter = +0.9')
plt.plot(sim1)

# %%
model = ARMA(sim1, order=(1,0))
result = model.fit()
print(result.summary())
print("μ={} ,ϕ={}".format(result.params[0],result.params[1]))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(1, 0)   Log Likelihood               -1376.855
# Method:                       css-mle   S.D. of innovations              0.958
# Date:                Sun, 22 Sep 2019   AIC                           2759.709
# Time:                        00:55:59   BIC                           2774.433
# Sample:                             0   HQIC                          2765.305
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0130      0.317     -0.041      0.967      -0.634       0.608
# ar.L1.y        0.9053      0.013     67.878      0.000       0.879       0.931
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1046           +0.0000j            1.1046            0.0000
# -----------------------------------------------------------------------------
# μ=-0.012951858696464572 ,ϕ=0.9053378856906691

# %%
result.plot_predict(start=900, end=1010)
plt.show()

# %%
rmse = math.sqrt(mean_squared_error(sim1[900:1011], result.predict(start=900,end=999)))
print("The root mean squared error is {}.".format(rmse))
# Out:
# The root mean squared error is 0.8532860289805512.

# %%
# Predicting closing prices of google
ibm_stock_pred = ARMA(ibm["Close"].diff().iloc[1:].values, order=(1,0))
res = ibm_stock_pred.fit()
res.plot_predict(start=900, end=1010)
plt.show()

# %%
def get_train_test_index(Ser,date):
    """
    Splits the data into train, test based on start date of test period
    """
    train = Ser[Ser.index < date]
    test = Ser[Ser.index >= date]
    return train, test

Ser = ibm.High
train, test = get_train_test_index(Ser,date='2017-01-12')
list(train.values)

[x for x in train]
# Out:
# [82.55,
#  82.5,
#  82.9,
#  85.03,
#  84.25,
#  84.12,
#  84.81,
#  83.96,
#  83.45,
#  83.16,
#  84.7,
#  84.39,
#  83.05,
#  81.92,
#  82.15,
#  81.62,
#  81.65,
#  81.77,
#  81.81,
#  82.0,
#  82.24,
#  81.59,
#  80.77,
#  79.95,
#  80.19,
#  80.9,
#  80.8,
#  81.46,
#  81.91,
#  81.45,
#  81.5,
#  80.91,
#  81.03,
#  80.75,
#  81.65,
#  81.34,
#  80.65,
#  80.89,
#  80.55,
#  80.81,
#  80.21,
#  80.83,
#  80.64,
#  80.79,
#  81.6,
#  81.98,
#  82.25,
#  82.4,
#  82.99,
#  83.76,
#  83.72,
#  83.41,
#  83.75,
#  84.99,
#  84.68,
#  84.27,
#  83.72,
#  83.26,
#  83.39,
#  83.55,
#  83.7,
#  83.6,
#  83.59,
#  83.78,
#  84.45,
#  84.32,
#  83.8,
#  82.74,
#  82.06,
#  81.37,
#  82.6,
#  82.92,
#  83.53,
#  84.0,
#  82.85,
#  82.5,
#  82.41,
#  82.9,
#  83.48,
#  84.4,
#  83.62,
#  83.31,
#  82.74,
#  83.29,
#  83.09,
#  83.34,
#  83.22,
#  83.29,
#  83.33,
#  83.09,
#  83.69,
#  83.15,
#  83.25,
#  82.21,
#  81.35,
#  81.0,
#  80.34,
#  81.3,
#  80.04,
#  80.18,
#  80.86,
#  80.96,
#  80.83,
#  80.87,
#  80.56,
#  80.04,
#  79.9,
#  80.74,
#  79.58,
#  78.1,
#  78.09,
#  77.93,
#  77.85,
#  78.78,
#  78.53,
#  78.3,
#  78.3,
#  78.56,
#  78.37,
#  77.84,
#  77.52,
#  77.6,
#  76.6,
#  77.8,
#  77.93,
#  78.27,
#  78.39,
#  78.53,
#  78.09,
#  76.83,
#  76.65,
#  76.3,
#  75.28,
#  74.3,
#  73.94,
#  74.42,
#  77.06,
#  75.88,
#  75.5,
#  76.15,
#  76.41,
#  76.3,
#  77.29,
#  77.3,
#  77.5,
#  77.38,
#  76.93,
#  76.73,
#  76.77,
#  76.2,
#  76.26,
#  76.28,
#  76.08,
#  75.78,
#  77.49,
#  77.14,
#  79.28,
#  79.56,
#  79.97,
#  79.88,
#  79.55,
#  79.47,
#  79.5,
#  80.0,
#  80.47,
#  81.48,
#  81.68,
#  81.5,
#  81.57,
#  81.54,
#  80.69,
#  80.38,
#  80.86,
#  81.2,
#  82.5,
#  82.7,
#  83.0,
#  83.59,
#  83.21,
#  82.09,
#  83.79,
#  83.25,
#  82.12,
#  82.28,
#  82.66,
#  82.67,
#  82.35,
#  82.79,
#  82.47,
#  82.26,
#  83.25,
#  83.21,
#  83.78,
#  84.08,
#  84.63,
#  84.69,
#  84.9,
#  86.21,
#  87.6,
#  87.94,
#  92.04,
#  90.98,
#  90.7,
#  92.0,
#  91.95,
#  91.99,
#  91.93,
#  91.89,
#  92.0,
#  92.68,
#  92.68,
#  91.95,
#  92.34,
#  92.74,
#  93.4,
#  92.92,
#  93.19,
#  92.35,
#  92.43,
#  93.29,
#  93.28,
#  93.6,
#  94.05,
#  93.8,
#  93.43,
#  93.74,
#  93.75,
#  93.24,
#  91.57,
#  91.66,
#  92.48,
#  91.91,
#  93.95,
#  94.64,
#  94.87,
#  94.43,
#  94.39,
#  94.35,
#  94.85,
#  95.33,
#  95.72,
#  95.8,
#  96.16,
#  96.39,
#  96.5,
#  96.5,
#  95.98,
#  95.81,
#  97.23,
#  97.4,
#  97.88,
#  98.4,
#  98.79,
#  97.95,
#  99.5,
#  100.33,
#  99.05,
#  99.9,
#  99.69,
#  100.84,
#  100.9,
#  99.95,
#  96.85,
#  97.23,
#  97.38,
#  97.58,
#  97.92,
#  97.83,
#  98.66,
#  99.45,
#  99.48,
#  99.18,
#  99.73,
#  100.44,
#  100.4,
#  100.36,
#  99.74,
#  99.7,
#  99.2,
#  98.74,
#  99.43,
#  99.52,
#  99.25,
#  99.46,
#  99.37,
#  99.5,
#  98.44,
#  97.86,
#  96.01,
#  94.09,
#  93.05,
#  92.37,
#  92.15,
#  93.89,
#  94.85,
#  94.82,
#  94.0,
#  94.17,
#  94.47,
#  94.03,
#  93.97,
#  94.45,
#  94.32,
#  94.53,
#  95.81,
#  95.44,
#  95.22,
#  95.25,
#  95.03,
#  95.02,
#  95.11,
#  94.75,
#  95.5,
#  96.23,
#  96.45,
#  96.75,
#  96.94,
#  96.8,
#  96.7,
#  95.82,
#  95.75,
#  96.3,
#  97.66,
#  95.91,
#  94.87,
#  95.15,
#  95.73,
#  99.9,
#  101.7,
#  101.5,
#  101.17,
#  103.0,
#  103.17,
#  103.14,
#  103.0,
#  103.03,
#  103.17,
#  103.39,
#  104.75,
#  105.11,
#  105.99,
#  106.25,
#  105.8,
#  105.89,
#  106.23,
#  108.05,
#  108.0,
#  107.25,
#  107.0,
#  105.98,
#  105.43,
#  106.63,
#  107.1,
#  107.67,
#  107.24,
#  106.59,
#  106.55,
#  105.51,
#  103.17,
#  103.21,
#  104.0,
#  103.18,
#  103.26,
#  104.24,
#  105.19,
#  105.65,
#  106.66,
#  107.02,
#  107.0,
#  106.44,
#  105.77,
#  106.06,
#  105.47,
#  106.92,
#  106.58,
#  105.8,
#  107.08,
#  108.39,
#  109.66,
#  109.35,
#  109.15,
#  109.6,
#  109.65,
#  109.2,
#  110.04,
#  111.47,
#  111.88,
#  116.48,
#  115.86,
#  116.43,
#  117.0,
#  118.38,
#  118.82,
#  117.95,
#  115.75,
#  114.72,
#  112.73,
#  114.05,
#  114.18,
#  113.89,
#  114.17,
#  114.6,
#  114.49,
#  113.5,
#  113.95,
#  113.15,
#  112.85,
#  111.42,
#  112.67,
#  111.1,
#  110.11,
#  110.5,
#  111.68,
#  113.25,
#  113.85,
#  113.59,
#  114.98,
#  116.0,
#  117.35,
#  118.89,
#  118.15,
#  118.75,
#  116.97,
#  117.5,
#  117.78,
#  117.4,
#  117.0,
#  116.0,
#  115.25,
#  116.78,
#  117.19,
#  117.65,
#  118.1,
#  117.43,
#  117.59,
#  118.08,
#  118.21,
#  118.5,
#  119.5,
#  119.6,
#  117.84,
#  116.75,
#  116.71,
#  118.23,
#  118.5,
#  118.8,
#  121.46,
#  118.89,
#  118.37,
#  119.94,
#  118.01,
#  116.41,
#  114.93,
#  113.88,
#  114.8,
#  114.45,
#  114.4,
#  114.0,
#  115.01,
#  114.9,
#  116.25,
#  116.09,
#  115.15,
#  115.11,
#  113.95,
#  113.64,
#  110.32,
#  104.92,
#  104.19,
#  105.74,
#  106.42,
#  105.64,
#  105.0,
#  105.39,
#  104.97,
#  104.09,
#  104.14,
#  105.15,
#  104.58,
#  108.27,
#  107.87,
#  109.19,
#  107.14,
#  107.42,
#  108.52,
#  110.0,
#  110.0,
#  110.26,
#  110.4,
#  110.2,
#  108.64,
#  107.56,
#  105.99,
#  106.97,
#  108.38,
#  109.49,
#  111.16,
#  112.0,
#  112.19,
#  111.3,
#  110.76,
#  110.0,
#  108.99,
#  105.57,
#  103.95,
#  101.0,
#  100.38,
#  99.15,
#  100.86,
#  99.46,
#  105.59,
#  104.64,
#  102.86,
#  103.45,
#  106.72,
#  103.09,
#  106.34,
#  107.51,
#  107.79,
#  105.77,
#  106.8,
#  107.65,
#  107.97,
#  109.4,
#  109.0,
#  108.05,
#  106.49,
#  104.0,
#  103.67,
#  105.55,
#  107.33,
#  108.93,
#  108.5,
#  106.25,
#  107.62,
#  108.21,
#  109.6,
#  108.48,
#  110.32,
#  114.99,
#  116.63,
#  115.9,
#  115.14,
#  114.81,
#  115.72,
#  116.41,
#  115.15,
#  114.75,
#  115.99,
#  116.56,
#  118.0,
#  116.78,
#  116.52,
#  117.04,
#  118.43,
#  118.5,
#  118.48,
#  119.79,
#  119.1,
#  117.97,
#  116.2,
#  116.75,
#  115.87,
#  118.37,
#  116.88,
#  116.82,
#  116.58,
#  117.37,
#  116.88,
#  117.72,
#  119.22,
#  117.8,
#  117.94,
#  117.67,
#  120.47,
#  123.72,
#  125.0,
#  124.51,
#  124.35,
#  124.78,
#  124.9,
#  124.5,
#  123.05,
#  123.2,
#  123.5,
#  124.43,
#  124.0,
#  123.25,
#  123.34,
#  124.98,
#  125.17,
#  124.65,
#  125.99,
#  126.7,
#  128.83,
#  128.68,
#  128.48,
#  128.21,
#  126.05,
#  126.4,
#  125.35,
#  124.91,
#  127.38,
#  129.54,
#  129.99,
#  129.99,
#  129.37,
#  129.0,
#  128.5,
#  129.04,
#  128.14,
#  126.18,
#  126.72,
#  125.9,
#  125.09,
#  126.57,
#  127.14,
#  127.1,
#  125.43,
#  125.62,
#  125.02,
#  124.5,
#  124.25,
#  125.83,
#  123.82,
#  122.05,
#  120.22,
#  119.36,
#  120.55,
#  120.78,
#  122.64,
#  123.99,
#  124.5,
#  123.54,
#  123.74,
#  124.25,
#  124.5,
#  126.89,
#  126.96,
#  130.0,
#  129.9,
#  130.0,
#  130.33,
#  130.93,
#  129.9,
#  128.44,
#  128.17,
#  129.0,
#  129.5,
#  129.3,
#  128.1,
#  128.9,
#  129.5,
#  129.97,
#  129.88,
#  128.43,
#  126.5,
#  126.99,
#  128.25,
#  127.19,
#  127.0,
#  124.79,
#  123.97,
#  123.43,
#  125.35,
#  124.93,
#  122.85,
#  124.85,
#  125.45,
#  123.99,
#  124.0,
#  118.65,
#  118.9,
#  115.09,
#  118.28,
#  118.1,
#  119.95,
#  119.37,
#  119.28,
#  118.41,
#  117.64,
#  115.5,
#  118.59,
#  124.0,
#  120.14,
#  118.17,
#  118.17,
#  121.99,
#  121.01,
#  118.43,
#  116.96,
#  116.8,
#  109.97,
#  110.95,
#  103.0,
#  102.62,
#  97.48,
#  95.31,
#  91.66,
#  93.61,
#  99.0,
#  95.29,
#  92.0,
#  95.91,
#  93.31,
#  92.46,
#  87.59,
#  85.89,
#  84.31,
#  84.5,
#  87.61,
#  91.0,
#  92.4,
#  94.19,
#  94.67,
#  94.76,
#  93.4,
#  88.83,
#  86.71,
#  88.1,
#  84.29,
#  82.4,
#  84.39,
#  85.4,
#  79.74,
#  80.93,
#  81.0,
#  78.39,
#  76.98,
#  82.09,
#  82.4,
#  81.79,
#  81.9,
#  81.36,
#  80.0,
#  81.0,
#  80.83,
#  81.5,
#  85.88,
#  85.43,
#  84.99,
#  82.86,
#  82.94,
#  83.54,
#  86.84,
#  87.27,
#  86.64,
#  85.22,
#  83.45,
#  82.81,
#  81.22,
#  81.8,
#  81.72,
#  83.64,
#  85.0,
#  87.59,
#  87.67,
#  90.41,
#  88.8,
#  88.14,
#  87.5,
#  86.6,
#  86.59,
#  84.82,
#  84.83,
#  85.74,
#  84.92,
#  91.6,
#  90.74,
#  90.7,
#  92.67,
#  91.97,
#  94.94,
#  94.58,
#  93.48,
#  91.86,
#  93.73,
#  94.91,
#  93.2,
#  97.1,
#  96.98,
#  96.82,
#  95.77,
#  95.2,
#  95.18,
#  92.49,
#  92.25,
#  92.16,
#  89.9,
#  89.33,
#  87.08,
#  87.12,
#  90.2,
#  93.28,
#  91.9,
#  90.18,
#  91.24,
#  90.16,
#  88.25,
#  86.8,
#  87.25,
#  89.54,
#  90.6,
#  90.65,
#  93.0,
#  92.91,
#  92.9,
#  93.35,
#  95.0,
#  98.71,
#  99.55,
#  99.86,
#  99.2,
#  96.0,
#  94.74,
#  98.66,
#  98.0,
#  101.99,
#  102.66,
#  101.85,
#  100.5,
#  101.55,
#  102.45,
#  101.65,
#  99.95,
#  99.06,
#  101.92,
#  102.04,
#  101.19,
#  102.48,
#  103.86,
#  102.78,
#  101.58,
#  101.69,
#  102.73,
#  105.0,
#  106.05,
#  104.86,
#  106.75,
#  106.82,
#  105.5,
#  104.8,
#  103.75,
#  103.88,
#  104.38,
#  103.1,
#  102.71,
#  103.07,
#  104.71,
#  106.12,
#  105.98,
#  103.25,
#  103.31,
#  105.63,
#  105.17,
#  105.14,
#  106.5,
#  108.67,
#  108.8,
#  106.6,
#  106.87,
#  108.4,
#  107.98,
#  109.14,
#  109.28,
#  110.64,
#  109.28,
#  108.83,
#  109.14,
#  107.88,
#  107.53,
#  106.65,
#  105.88,
#  104.87,
#  106.48,
#  106.78,
#  106.5,
#  106.18,
#  106.03,
#  106.27,
#  103.91,
#  102.23,
#  101.96,
#  101.17,
#  102.78,
#  101.72,
#  103.65,
#  103.62,
#  107.22,
#  110.97,
#  115.53,
#  116.88,
#  117.04,
#  117.2,
#  118.0,
#  118.15,
#  117.92,
#  117.52,
#  117.28,
#  119.37,
#  118.99,
#  119.96,
#  119.8,
#  119.0,
#  118.4,
#  119.91,
#  119.19,
#  118.5,
#  119.96,
#  119.78,
#  119.74,
#  117.44,
#  118.0,
#  118.77,
#  119.41,
#  120.01,
#  120.88,
#  120.15,
#  119.85,
#  119.59,
#  120.23,
#  118.06,
#  118.93,
#  117.24,
#  116.73,
#  117.5,
#  118.17,
#  117.67,
#  117.83,
#  119.25,
#  118.99,
#  119.45,
#  122.0,
#  122.78,
#  122.88,
#  122.08,
#  122.11,
#  122.74,
#  121.65,
#  121.65,
#  122.0,
#  119.94,
#  120.0,
#  119.61,
#  119.66,
#  120.18,
#  121.59,
#  122.85,
#  122.98,
#  126.0,
#  127.1,
#  127.39,
#  128.61,
#  128.0,
#  123.7,
#  123.36,
#  123.5,
#  124.11,
#  123.0,
#  123.06,
#  122.44,
#  122.14,
#  121.68,
#  123.03,
#  124.3,
#  121.93,
#  121.19,
#  122.5,
#  123.5,
#  123.49,
#  126.0,
#  127.05,
#  127.3,
#  127.65,
#  127.8,
#  128.24,
#  128.66,
#  128.35,
#  127.84,
#  127.69,
#  128.94,
#  128.32,
#  128.22,
#  126.62,
#  126.6,
#  128.39,
#  128.39,
#  128.47,
#  128.9,
#  127.53,
#  127.35,
#  128.39,
#  129.47,
#  129.77,
#  129.98,
#  129.86,
#  129.6,
#  128.56,
#  128.39,
#  128.94,
#  ...]

# %%
from sklearn.metrics import mean_squared_error

# Predict stock prices for Dec'17

training_period_date = '2017-12-02'
train, test = get_train_test_index(Ser,training_period_date)
history = [x for x in train]
prediction = []
for t in range(len(test)): #Looping through each test period 
    model = ARIMA(history, order = (4,1,1))
    model_fit  = model.fit(disp=0)
    output = model_fit.forecast()
    y_hat = output[0]
    prediction.append(y_hat)
    obs = test[t]
    history.append(obs)
#     print(f'predicted : {y_hat}, Expected : {obs}')
error = mean_squared_error(test, prediction)
print(f'Test MSE: {error}')
plt.plot(test)
plt.plot(prediction, color='red')
plt.legend(['Test', 'Observation'])
plt.show()
# Out:
# Test MSE: 1.0604313430255887

# %%
pred_list = [float(i) for i in prediction]
pred_df = pd.DataFrame(columns = ['Observed', 'Predicted'], index=test.index)
pred_df['Observed']=test.values
pred_df['Predicted']=pred_list
pred_df.plot()

# %% [markdown]
# # Vector autoregression  VAR models
#
# - VAR is a stochastic process model used to capture the linear interdependencies among multiple time series. VAR models generalize the univariate autoregressive model (AR model) by allowing for more than one evolving variable. All variables in a VAR enter the model in the same way: each variable has an equation explaining its evolution based on its own lagged values, the lagged values of the other model variables, and an error term

# %% [markdown]
# # Facebook's Prophet for TS prediction

# %%
from fbprophet import Prophet

# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width=0.95)

prophet_df = ibm.reset_index().rename({"Date":"ds", "High":"y"}, axis=1)[["ds", "y"]]
my_model.fit(prophet_df)

# Creating prediction set
future_dates = my_model.make_future_dataframe(periods=30, freq='D')
future_dates.tail()

# Forecasting
# ds: the datestamp of the forecasted value
# yhat: the forecasted value of our metric
# yhat_lower: the lower bound of our forecasts
# yhat_upper: the upper bound of our forecasts


# Note: Prophet uses Markov chain Monte Carlo (MCMC) for forecasts, so there will be variation in results everytime.

forecast = my_model.predict(future_dates)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(30)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#              ds        yhat  yhat_lower  yhat_upper
# 3020 2017-12-30  157.677843  141.975520  172.115751
# 3021 2017-12-31  157.691735  142.636745  174.284895
# 3022 2018-01-01  155.166218  139.565933  170.469924
# 3023 2018-01-02  155.298040  139.356153  169.811054
# 3024 2018-01-03  155.391486  138.992985  169.170293
# 3025 2018-01-04  155.503830  141.660819  170.068862
# 3026 2018-01-05  155.325911  140.075900  170.684640
# 3027 2018-01-06  157.917222  142.281053  172.087559
# 3028 2018-01-07  157.980402  141.684717  173.323434
# 3029 2018-01-08  155.504945  139.575931  172.346649
# 3030 2018-01-09  155.686295  140.221378  171.194055
# 3031 2018-01-10  155.827494  140.307157  171.819894
# 3032 2018-01-11  155.984662  140.619656  172.236083
# 3033 2018-01-12  155.847610  140.729634  170.431022
# 3034 2018-01-13  158.474958  143.439165  173.823522
# 3035 2018-01-14  158.568650  143.857980  174.481850
# 3036 2018-01-15  156.117675  140.791247  171.925011
# 3037 2018-01-16  156.317179  140.328515  172.541699
# 3038 2018-01-17  156.470111  140.924972  171.114875
# 3039 2018-01-18  156.632708  141.281052  171.012739
# 3040 2018-01-19  156.495093  140.482569  172.140981
# 3041 2018-01-20  159.116377  143.218450  174.680846
# 3042 2018-01-21  159.199156  144.222292  174.652822
# 3043 2018-01-22  156.733209  141.369270  172.156192
# 3044 2018-01-23  156.914574  141.410786  173.633774
# 3045 2018-01-24  157.047168  141.837273  172.989514
# 3046 2018-01-25  157.188230  140.434328  172.615380
# 3047 2018-01-26  157.028889  141.178327  172.393110
# 3048 2018-01-27  159.629236  143.945411  174.608867
# 3049 2018-01-28  159.692777  145.280368  174.913744

# %%
my_model.plot(forecast, uncertainty=True)

# Prophet plots the observed values of our time series (the black dots)
# the forecasted values (blue line) and the uncertainty intervals of our forecasts (the blue shaded regions).

# %%
my_model.plot_components(forecast)

# %% [markdown]
# - Since cycles in stock market we want to figure out are not limited to yearly, weekly or daily, we should define our own cycles and find out which can fit the data better. Besides, we should not use weekly seasonality since there is no trading on weekend.

# %%
m = Prophet(weekly_seasonality=False,yearly_seasonality=False)
m.add_seasonality('self_define_cycle',period=8,fourier_order=8,mode='additive')

# %%
def cycle_analysis(data, split_date, cycle, mode='additive', forecast_plot = False, print_ind=False):
    
    # Create train / test data
    train = data[:split_date].iloc[:-1,]
    print(f'Training period: {train.index[0], train.index[-1]}')
    
    test = data[split_date:]
    print(f'Training period: {test.index[0], test.index[-1]}')
    
    test.index = pd.to_datetime(test.index)
    
    predict_period = len(pd.date_range(split_date, max(data.index)))
    
    df = train.reset_index()
    df.columns = ['ds','y']
    
    m = Prophet(weekly_seasonality=True,yearly_seasonality=False,daily_seasonality=False)
    m.add_seasonality('self_define_cycle',period=cycle,fourier_order=8,mode=mode)
    m.fit(df)
    
    future = m.make_future_dataframe(periods=predict_period)
    forecast = m.predict(future)
    
    if forecast_plot:
        m.plot(forecast)
        plt.plot(test.index,test.values,'.',color='#ff3333',alpha=0.6)
        plt.xlabel('Date',fontsize=12,fontweight='bold',color='gray')
        plt.ylabel('Price',fontsize=12,fontweight='bold',color='gray')
        plt.show()
        
    ret = max(forecast.self_define_cycle)-min(forecast.self_define_cycle)
    
    model_tb = forecast['yhat']
#     model_tb.index = forecast['ds'].map(lambda x:x.strftime("%Y-%m-%d"))
    out_tb = pd.concat([test, model_tb],axis=1, sort=False)
    
#     print(out_tb)
    
#     out_tb = out_tb[~out_tb.iloc[:,0].isnull()]
#     out_tb = out_tb[~out_tb.iloc[:,1].isnull()]
    
#     mse = mean_squared_error(out_tb.iloc[:,0],out_tb.iloc[:,1])
#     rep = [ret,mse]
    
#     if print_ind:
#         print("Projected return per cycle: {}".format(round(rep[0],2)))
#         print("MSE: {}".format(round(rep[1],4)))
    
    return out_tb

# %%
out = cycle_analysis(ibm.Close[ibm.index>'2014-06-01'], '2017-11-01', cycle=90, mode='multiplicative',
               forecast_plot = True, print_ind=True)
# Out:
# Training period: ('2014-06-02', '2017-10-31')
# Training period: ('2017-11-01', '2017-12-29')

# %%
out.yhat.notnull().sum()
# Out:
# 0

# %%
cycle_analysis(msft.Close, '2017-10-01', cycle=30, mode='additive', forecast_plot = False, print_ind=True)
# Out:
# Training period: ('2006-01-03', '2017-09-28')
# Training period: ('2017-10-02', '2017-12-29')
#                                Close  yhat
# 1970-01-01 00:00:00.000000000    NaN   NaN
# 1970-01-01 00:00:00.000000001    NaN   NaN
# 1970-01-01 00:00:00.000000002    NaN   NaN
# 1970-01-01 00:00:00.000000003    NaN   NaN
# 1970-01-01 00:00:00.000000004    NaN   NaN
# ...                              ...   ...
# 2017-12-22 00:00:00.000000000  85.51   NaN
# 2017-12-26 00:00:00.000000000  85.40   NaN
# 2017-12-27 00:00:00.000000000  85.71   NaN
# 2017-12-28 00:00:00.000000000  85.72   NaN
# 2017-12-29 00:00:00.000000000  85.54   NaN
#
# [3108 rows x 2 columns]

# %%
cycle_analysis(amazon.Close, '2017-10-01', cycle=30, mode='additive', forecast_plot = False, print_ind=True)
# Out:
# Projected return per cycle: 4.77
# MSE: 7295.3318
# [4.7654622793109915, 7295.331816100917]

# %% [markdown]
# # Understanding effect of tweets on Stock Prices

# %%
from twitterscraper import query_tweets
import jsonpickle

# All tweets matching either Trump or Clinton will be returned. You will get at
# least 10 results within the minimal possible time/number of requests
ibm_tweets = []
for tweet in query_tweets("IBM", 10)[:10]:
    ibm_tweets.append(tweet.user.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-421-15278f6a7397> in <module>
#       1 from twitterscraper import query_tweets
# ----> 2 import jsonpickle
#       3
#       4 # All tweets matching either Trump or Clinton will be returned. You will get at
#       5 # least 10 results within the minimal possible time/number of requests
#
# ModuleNotFoundError: No module named 'jsonpickle'

# %%
import jsonpickle

# %%
# def get_tweets(listOfTweets, keyword, numOfTweets):
    
for tweet in tweepy.Cursor(api.search, q='ibm').items(2):
    dict_ = {
        'Screen Name': tweet.user.screen_name,
        'User Name': tweet.user.name,
        'Tweet Created at' : tweet.created_at,
        'User Location': tweet.user.location,
        'Tweet Coordinates': tweet.coordinates,
        'Retweet Count': tweet.retweet_count,
        'Retweeted': tweet.retweeted,
        'Phone Type': tweet.source,
        'Favorite Count': tweet.favorite_count,
        'Favorited': tweet.favorited,
        'Replied': tweet.in_reply_to_status_id_str
    }
    
dict_
# Out:
# {'Screen Name': 'CivilJulianR',
#  'User Name': 'JuliánRodríguez',
#  'Tweet Created at': datetime.datetime(2019, 9, 25, 23, 32, 10),
#  'User Location': 'Dnde el Diablo olvido la Ruana',
#  'Tweet Coordinates': None,
#  'Retweet Count': 4097,
#  'Retweeted': False,
#  'Phone Type': 'Twitter for Android',
#  'Favorite Count': 0,
#  'Favorited': False,
#  'Replied': None}

# %%
def get_tweets(listOfTweets, keyword, numOfTweets):
    return_df = pd.DataFrame()
    # Iterate through all tweets containing the given word, api search mode
    for tweet in tweepy.Cursor(api.search, q=keyword).items(numOfTweets):
        # Add tweets in this format
        dict_ = {
            'Screen Name': [tweet.user.screen_name],
            'User Name': [tweet.user.name],
            'Tweet Created at' : [tweet.created_at],
            'Retweeted': [tweet.retweeted],
            'Replied': [tweet.in_reply_to_status_id_str]
                }
        # Create a df object for the tweet
        df_ = pd.DataFrame(dict_)
        #columns = ['Screen Name', 'User Name', 'Tweet Created at', 'Retweeted', 'Replied']
        
        return_df.append(df_)   
    return df_

get_tweets(listOfTweets=[], keyword='ibm', numOfTweets=2)
# Out:
#   Screen Name   User Name    Tweet Created at  Retweeted Replied
# 0   DORGE1255  EL LLANERO 2019-09-26 00:06:23      False    None

# %%
import tweepy
import re
 
from tweepy import OAuthHandler

# Setup access API
def connect_to_twitter_OAuth():
    consumer_api_key = 'PiiHB6E27r4CmqWJgSTISGHbL'
    consumer_api_secret = 'jBlolQXKuZM8Qqmrz4of0vltss6IJx4ndOM0VZQf9bBpQXpHbn' 
    access_token = '148054901-ZB3kFyazdpAvV6x19IElkGEVZ5iHB43qPLI0XXVT'
    access_token_secret ='2zXooUBLzubEDgDSitnyeXeO3MvXBj9lAQLtQLfowsWaG'
    
    auth = tweepy.OAuthHandler(consumer_api_key, consumer_api_secret)
    auth.set_access_token(access_token, access_token_secret)
    
    api = tweepy.API(auth)
    return api 


api = connect_to_twitter_OAuth()
api

# %%
def get_save_tweets(filepath, api, query, max_tweets=100000, lang='en'):
    tweetCount=0
    
    # Open a file and save tweets
    with open(filepath, 'w') as f:
        
        # Query tweets
        for tweet in tweepy.Cursor(api.search, q=query, lang=lang).items(max_tweets):
            
            # Convert to JSON format
            f.write(jsonpickle.encode(tweet.__json, unpickable=False) + '\n')
            tweetCount=+1
            
            # Display count of tweets collected 
            print("Downloaded {0} tweets".format(tweetCount))

# %%
def get_save_tweets(filepath, api, query, max_tweets=1000000, lang='en'):

    tweetCount = 0

    #Open file and save tweets
    with open(filepath, 'w') as f:

        # Send the query
        for tweet in tweepy.Cursor(api.search,q=query,lang=lang).items(max_tweets):         

            #Convert to JSON format
            f.write(jsonpickle.encode(tweet._json, unpicklable=False) + '\n')
            tweetCount += 1

        #Display how many tweets we have collected
        print("Downloaded {0} tweets".format(tweetCount))

# %%
query = '#ibm'

# Get those tweets
get_save_tweets('tweets.json', api, query)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-446-524fbfb43705> in <module>
#       2
#       3 # Get those tweets
# ----> 4 get_save_tweets('tweets.json', api, query)
#
# <ipython-input-445-f9b4740324af> in get_save_tweets(filepath, api, query, max_tweets, lang)
#       7
#       8         # Send the query
# ----> 9         for tweet in tweepy.Cursor(api.search,q=query,lang=lang).items(max_tweets):
#      10
#      11             #Convert to JSON format
#
# /anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# /anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# /anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# /anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
def tweets_to_df(path):
    
    tweets = list(open('tweets.json', 'rt'))
    
    text = []
    weekday = []
    month = []
    day = []
    hour = []
    hashtag = []
    url = []
    favorite = []
    reply = []
    retweet = []
    follower = []
    following = []
    user = []
    screen_name = []

    for t in tweets:
        t = jsonpickle.decode(t)
        
        # Text
        text.append(t['text'])
        
        # Decompose date
        date = t['created_at']
        weekday.append(date.split(' ')[0])
        month.append(date.split(' ')[1])
        day.append(date.split(' ')[2])
        
        time = date.split(' ')[3].split(':')
        hour.append(time[0]) 
        
        # Add user
        user.append(t['user']['name'])

        
    d = {'text': text,
         'weekday': weekday,
         'month' : month,
         'day': day,
         'hour' : hour,
         'user': user,
        }
    
    return pd.DataFrame(data = d)
        
tweets_df = tweets_to_df('tweets.json')

# %%
tweets_df

# %%
tweets = pd.read_csv("https://raw.githubusercontent.com/kolaveridi/kaggle-Twitter-US-Airline-Sentiment-/master/Tweets.csv")

# %%
tweets.shape
# Out:
# (14640, 15)

# %%
import nltk 
nltk.download('stopwords')  
from nltk.corpus import stopwords 

X = tweets.iloc[:, 10].values  
y = tweets.iloc[:, 1].values
 
processed_tweets = []
 
for tweet in range(0, len(X)):  
    # Remove all the special characters
    processed_tweet = re.sub(r'\W', ' ', str(X[tweet]))
 
    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)
 
    # Remove single characters from the start
    processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet) 
 
    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)
 
    # Removing prefixed 'b'
    processed_tweet = re.sub(r'^b\s+', '', processed_tweet)
 
    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()
 
    processed_tweets.append(processed_tweet)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/praneeshkhanna/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ### TF-IDF for Text to Numeric Conversion

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
tfidfconverter = TfidfVectorizer(max_features=2000, min_df=5, max_df=0.7, stop_words=stopwords.words('english'))  
X = tfidfconverter.fit_transform(processed_tweets).toarray()

from sklearn.ensemble import RandomForestClassifier
text_classifier = RandomForestClassifier(n_estimators=100, random_state=0)  
text_classifier.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
for tweet in all_tweets:
    # Remove all the special characters
    processed_tweet = re.sub(r'\W', ' ', tweet)
 
    # remove all single characters
    processed_tweet = re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_tweet)
 
    # Remove single characters from the start
    processed_tweet = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_tweet) 
 
    # Substituting multiple spaces with single space
    processed_tweet= re.sub(r'\s+', ' ', processed_tweet, flags=re.I)
 
    # Removing prefixed 'b'
    processed_tweet = re.sub(r'^b\s+', '', processed_tweet)
 
    # Converting to Lowercase
    processed_tweet = processed_tweet.lower()
 
    sentiment = text_classifier.predict(tfidfconverter.transform([ processed_tweet]).toarray())
    print(processed_tweet ,":", sentiment)
# Out:
# i went to the meeting with pm narendramodi optimistic but come out even more optimistic about india says ibm https co rebocyojix : ['neutral']
#  okolie_ibm when you win let me know : ['negative']
# seriously need to know why mbuhari is always off point it baffles me with the way he responds to questions he https co rycljgoagq : ['neutral']
#  avaya and ibm have unveiled an agreement in which avaya will adopt hybrid cloud solutions from ibm to help expan https co u3vqfseqrm : ['neutral']
#  iiug iiugworld ww_informix hcltech fyi got to know the news about my award while did some initial tests of https co jep9j341fu : ['neutral']
#  ibm ceo ginnirometty asserted that she come out even more optimistic about india https co f1rhriw3vw : ['neutral']
# thanks ginnirometty ma am proud to be an ibm er https co kdle7cqzpg : ['positive']
# with ibm power 9 becoming available in 2018 ibm didn just improve over its own power products but also increa https co dmnqwhjiio : ['negative']
# science ftw ibm just announced robotics competition to stop the winner of the previous competition https co yg40fnpnxv : ['neutral']
#  the algae collection was part of the jefferson project water quality monitoring and mapping effort carried ou https co bvcfbkgjsy : ['neutral']
# 5 cyber skills that are essential for the security industry next decade https co qj2xxhl8m6 cyberskills security : ['negative']
# looking for ibm training from trusted name in the it certification training space ingram micro is one of only https co itknfjp0at : ['negative']
# enterprises are moving towards hybrid approach in their cloud strategies and we re proud to be part of it ou https co fxvistab0c : ['neutral']
# enterprises are moving towards hybrid approach in their cloud strategies and we re proud to be part of it ou https co 3myjyapid0 : ['neutral']
#  redhat discusses how rhel8 available on the newest linuxone helps pave the way for the rest of their hybrid clo https co m2nvrioopk : ['neutral']
# we are pleased to announce that ibm maximo enterprise asset management software has attained impact level 2 of https co 9udyqelxps : ['neutral']
# hey ve just discovered how ibm is helping to improve lives and communities in africa by putting smart to work https co ejqvovglne : ['neutral']
#  ibm cloud application platform facilitates application modernization and cloudnative application development via https co hkpweqe1xx : ['neutral']
# ibm steve canepa is innovating for 5g world https co 1t8x1ajuft : ['neutral']
# ibm is leading digitaltransformation with an enterprise health cloud that helps clients solve mission critical pr https co k01o6pkz3o : ['neutral']
# great people better results with hr solutions powered by ai you can create new ways of working get started on https co dyyrrxsjdq : ['positive']
# read about the opportunity for women to not only contribute to artificial intelligence i but help lead in its https co vxhknkyffn : ['neutral']
# the ibmsecurity community fall calendar is full of great webinars tech talks and user groups find an event that https co v6e2opph43 : ['positive']
# as the universe of digital payments has exploded in recent years the need for universal iso 20022 adoption is more https co 97jy2rpckj : ['neutral']
# i went to the meeting with pm narendramodi optimistic but come out even more optimistic about india says ibm https co d4w5z93pso : ['neutral']
#  ianujagnihotri pmoindia cocacolaco narendramodi ibm ginnirometty thanks for kind words  : ['positive']
# registration is just going on at the ibm innovation center today we ll be identifying the major obstacles to consi https co ukwc8nkxyc : ['neutral']
#  pmoindia narendramodi ibm ginnirometty went to the meeting with pm narendramodi optimistic but come out https co 0efg7qcytx : ['neutral']
#  pmoindia narendramodi ibm ginnirometty fake rape case on the rise in india mentoo : ['negative']
#  pmoindia narendramodi ibm ginnirometty hope you look after modiji and continue with the investments which are https co jgcu9bptjv : ['neutral']
#  pmoindia shell went to the meeting with pm narendramodi optimistic but come out even more optimistic about https co fno0vxbvav : ['neutral']
#  pmoindia narendramodi ibm ginnirometty went to the meeting with pm narendramodi optimistic but come out https co rialb0fu28 : ['neutral']
#  pmoindia narendramodi ibm ginnirometty what proud moment for me am so luck to be part of ibm  : ['negative']
#  pmoindia narendramodi ibm ginnirometty really excited to be in the prime minister investment summit says jam https co tua666stol : ['neutral']
#  rahulgandhi priyankagandhi shashitharoor rssurjewala ibm ceo she is justsaying https co vymapddms6 : ['neutral']
#  pmoindia narendramodi ibm ginnirometty here what the ceo of bankofamerica brian moynihan has to say on https co lxcvjs93ei : ['neutral']
#  pmoindia narendramodi ibm ginnirometty the meeting with pm narendramodi was excellent congratulate india https co 705i7il5z9 : ['neutral']
#  pmoindia narendramodi lockheedmartin went to the meeting with pm narendramodi optimistic but come out eve https co ii3zyr3ksa : ['neutral']
#  pmoindia narendramodi ibm ginnirometty even more optimistic is bombastic  : ['negative']
#  pmoindia narendramodi ibm ginnirometty they say like that only we have to set up our own business competing https co hmgdfzlf7x : ['neutral']
#  pmoindia narendramodi ibm ginnirometty pm great : ['positive']
#  pmoindia bankofamerica narendramodi went to the meeting with pm narendramodi optimistic but come out even https co iyuooqtj8p : ['neutral']
#  pmoindia narendramodi ibm ginnirometty come ask bjp leader commiting rape but walks free : ['negative']
#  pmoindia narendramodi ibm ginnirometty the health and wellness centers is not in gd condition in up : ['negative']
#  pmoindia cocacolaco went to the meeting with pm narendramodi optimistic but come out even more optimistic https co hmmsm62heg : ['neutral']
#  pmoindia narendramodi ibm ginnirometty hope to see more it jobs and it parks : ['negative']
#  pmoindia narendramodi ibm ginnirometty great pm modi : ['positive']
# i went to the meeting with pm narendramodi optimistic but come out even more optimistic about india says ibm https co dzn98ficlr : ['neutral']
#  pmoindia narendramodi ibm ginnirometty hope the can invest heavily in india after this  : ['negative']
# did you know that suse manager handles sap system configuration management for both suse and other linux distros https co rvbotbbpnx : ['neutral']
#  sandravandepere annagarriga3 geri_j7 ibm apple  : ['negative']
# i went to the meeting with pm narendramodi optimistic but come out even more optimistic about india says ibm https co 7awipp9saw : ['neutral']
# osgi community event 2019 eclipsecon in october featured talk osgi in action how we use osgi to build open lib https co ramwbgnkxa : ['neutral']
# and one month later they ve done exactly this fantastic initiative and super attendance mastercard kkr_co https co qrorrjio8q : ['negative']
# talent development ibm talent management watson talent https co txvjhpi88j : ['neutral']
# ted julian of ibm lays out the potential time savings from automating phishing security https co tlma9hozqy https co gf7jfzfk1r : ['neutral']
# iom is looking for senior itc programme assistant ibm have bsc msc in computer science telecommunications en https co ptsnca3a4q : ['neutral']
# ibm design thinking training and resources designthinking ibm via https co zjarusxikn https co ywkkduvllk : ['neutral']
# what really interests me here is recent discission of double exponential growth of quantum processor power this https co ta4howhtit : ['neutral']
# some of my favorite likes from npratc today good morning it only wednesday which is weird right https co iuo08xefku : ['neutral']
# marxism leninism is cringe and you can prove me wrong : ['negative']
# thank you team ingram micro for the today meeting which is an energizing start to make ibm cloud platform succe https co 5esrlqmd5j : ['positive']
# what settings should be reviewed when the user is unable to submit an interactive bsub job in spectrum lsf https co zhgxwl76gs : ['neutral']
#  rickhholland cynjachasec who me the last time used notes was ibm in 2007  : ['negative']
#  chewablefritter my first was an apple iie in 89 followed by an ibm aptiva in 95  : ['negative']
# isam specialist ibm security access manager job opening in dallas tx techjobs itjobs https co 9aqrtqwdx9 : ['negative']
#  chewablefritter literally just called the ibm personal computer or model 5150 : ['negative']
# meet floridastate graduate randy bruno piverger who recently began his new career as an ibm software engineer https co g73bcgx6vx : ['neutral']
# segment announces the winners of its inaugural data momentum awards ibm proposify ab inbev and upsolve https co 6jzmaaqasu : ['neutral']
# ibm presents new blockchain platform optimized for openshift https co hqnsafnvi3 https co eliltnttwv : ['neutral']
# reinventing clinicaltrials delivering on the vision of digitaltransformation in health at scale amp at pace https co qptb0rgitn : ['neutral']
# a critical inflection point for asset transformation are you ready https co dhqmksbbcp iot https co bb3mupitct : ['neutral']
#  ethanstone03 selfishenigmaaa check out her ibm page young actress get back to me when you check out who she https co owaqulbmlk : ['negative']
#  20 years is long time in terms of technology cultural shifts and audience preference don believe me in 1999 https co v2vfns6s7m : ['neutral']
# pros some great people make working for ibm bearable close to home cons management is more concerned process th https co zdmq98z2io : ['positive']
# ibm adds william mcnabb iii fmr chm ceo the vanguard group to board ibm corpgov https co ijl0i1e7la : ['neutral']
# corus360 expands ibm power solution support amp capabilities https co 9gegtz5cc5 : ['neutral']
# breaking news chaudhari leaves ibm for general electric cio job https co i2olx036dc https co ucmv16idh7 : ['neutral']
# learning what it takes to be agile at ibm https co y0m2tka1df : ['neutral']
# a critical inflection point for asset transformation are you ready https co dlavbhm8k3 : ['neutral']
# global big data platform market 2019 by companies google aws ibm dell market segment https co ddkdlaerrb bigdata dataanalysis : ['neutral']
# high performance platforms underpin fintech innovation https co nfi1gm6ns1 linuxone opensource : ['neutral']
#  onomeonyinye headlines current 4time nominee loses focus in life as an oneme called him nobody https co 7fjpiz4i6b : ['neutral']
#  judacris needs my thinkpads to be ugly black slabs with magnesium frames lots of ports and can be used to beat https co 4uidvvn0ce : ['neutral']
#  seven words was all it took for him to create an opportunity for me to both speak and further my career https co bhiwlgycd9 : ['neutral']
# angelmd ibm watson health ge healthcare philips aetna cvs health company bill amp melinda gates foundation bill ga https co wgx6zxbx4f : ['neutral']
#  onomeonyinye yes oo m nobody but by his grace m taking steps award winning a currently nominee for https co 2lrmplasyg : ['neutral']
# segment announces the winners of its inaugural data momentum awards ibm proposify ab inbev and upsolve https co sv8ynygnkc : ['neutral']
# data breach costs on the rise ibm study shows 7wdata https co vd3adrf6m7 via rightrelevance thanks yvesmulkers : ['positive']
# set and ready for tomorrow looking forward meeting 238 data practitioners at our 4th annual data2020 summit https co e5t7qqlwim : ['neutral']
# how is ptech helping cities in the us reimagine college https co emgokvyqqb via politico https co xqkpsyub9u : ['neutral']
#  shinedotcom ibm genpact icon netqube infinite pwc sbi hewlett packard universal adviser radical minds re https co kwssxfjlss : ['neutral']
#  fortunemagazine lockheedmartin mtbarra gm ginnirometty ibm anthembcbs generaldynamics we salute safra catz https co dbsvt2csgk : ['neutral']
# segment announces the winners of its inaugural data momentum awards ibm proposify ab inbev and upsolve https co 2qe2y9zmog : ['neutral']
# james kobielus sees multicloud as the strategy of the second tier cloud vendors https co wv3a3xyi98 https co lhgqqhvu4e : ['neutral']
# my father was ibm first black software engineer the racism he fought persists in the high tech world today https co 2onqg6efuq : ['negative']
# in this 2 minute video ibm fellow bala rajaraman takes us through the new ibm multicloud manager the enterpris https co r5zbkxvyby : ['neutral']
# fidel did nothing wrong https co bvecesozr7 https co miiakozfql : ['neutral']
# ibm looking to join facebook libra cryptocurrency https co 1a5brb5mqc https co rvy8af7ixm : ['neutral']
# geisinger ibm develop new predictive algorithm to detect sepsis risk https co sj4gzyjxis : ['neutral']
# think big start small and move fast here are the 10 new hr rules that have the potential to change the future of https co ffg7hmjwus : ['negative']
#  ibmregtech summit takes place tomorrow in london mikecurr55 is just one of our great speakers stay tuned check https co ihmgnnkgov : ['positive']
# ibm spectrum lsf enables easy deployment maximum uptime and performance at scale critical to success with hpc https co sbvljufp90 : ['neutral']
#  deeja_ibm yesso my sister  : ['negative']
# ok but this isn news the google quad campus mentioned is the former netscape campus and we knew about this 20 https co 5wybr6ynox : ['neutral']
# need deeper analytics to analyze how your video content is being viewed see how individual viewer analytics can https co tgiccn4mjy : ['neutral']
# gender issues committee and career services joined forces in welcoming homecoming panel of alumni to discuss the https co vifrlwol33 : ['neutral']
# oim recruits 01 intern ibm programme support https co cxoshorgdm : ['neutral']
# ibm offers free cybersecurity training to local governments https co axqe0v15kj : ['neutral']
# oim recruits 01 intern ibm programme support https co lkwxcxhmaq : ['neutral']
# most people in vietnam don have bank techcombank wants to change that ibm industries https co awd8qdqnis https co wlauns8nra : ['neutral']
# researchers learn about incidence based mortality https co h7eysbdijf https co 3gaqz66f9d : ['neutral']
#  ktowncampbells baked76 maximebernier sounds like what the united states did for most of ww2 while ibm and many https co eempvb3uqn : ['negative']
# congratulations to ibm for winning the best innovation in intelligent automation award at the aiconics tech https co 5yeylajq1z : ['positive']
# healthy offices efficient buildings and happy employees is winning combination see entelligently in action at https co r9ztlaofcx : ['neutral']
# find out everything you ever wanted to know about the england squad via the new england rugby website designed by https co bdvsoqz1ec : ['neutral']
# hey ve just discovered how ibm is helping to improve lives and communities in africa by putting smart to work https co wn8nt3hanx : ['neutral']
# lxer destination linux 136 raspberry pi system76 firmware tool obs ibm open source power https co mz2bb06fh8 : ['neutral']
# reading beckershr ibm to develop ai medical imaging system for cancer diagnosis monitoring https co qq1i8zt5rc : ['neutral']
# ibm watson advertising is here to help you build brand success let start with your personal brand bring your be https co wqd3ldqvwh : ['negative']
# true quantum supremacy has not yet been realized ibm says https co llqov2y1dg : ['neutral']
# in sector dominated by elephants goog fb ibm it nice to see the leader in quantum computing from burnaby https co y5uyopgkcz : ['neutral']
#  ibm chairman president amp ceo ms ginnirometty joins the power packed panel of key us industry leaders to discuss https co plegv542iq : ['neutral']
# your customers want secure reliable multicloud experience can you deliver it to them join our webinar to learn https co rs3qtxgdoj : ['negative']
#  onomeonyinye twitter should find way of dividing the rich and the poor or at least allow people make research : ['negative']
# ibm watson studio desktop best saas product for non profits amp education arinbhowmick https co mbbkehigid : ['positive']
# why ibm power for sap hana see below https co vsaruedif3 : ['neutral']
#  ibm_uk_news bernardmarr sallyeaves dt that 4 good looking people right there looking forward to it  : ['negative']
# ibm mobile first solution architect qatar michael page international uae limited september 25 201  : ['negative']
# ibm mobile first developer qatar michael page international uae limited september 25 201  : ['negative']
#  yaksmeer love both : ['positive']
#  timbray ibm makes its hiring decisions based on skills and business demands not on age but not its firing ones amirite  : ['negative']
#  okolie_ibm _zieofficial it from your phone check well it 2019 : ['negative']
#  blockchain potential to revolutionize crowdfunding https co qp8fnydwrq https co oc4hq3uhto : ['neutral']
# ibm developer strong cup of java episode two jakarta ee 8 launch https co w9bg2muffx : ['neutral']
# ibm developer strong cup of java episode one about jakarta ee https co ltgxberomc : ['neutral']
# ibm open editor brings cobol and pl language support to microsoft visual studio code mainframe dev https co gdbzbuhwsf : ['neutral']
# stay connected by joining the ibm security community thanks for sharing this sean mchugh cissp ccsp https co oklqvnmx60 : ['positive']
# somewhat belatedly here are the slides davemulley and wrote for the ibm hursley application modernisation summi https co paiajjafvl : ['neutral']
# being human in the age of ai https co lyfnquvxmc https co 3jrvbagqox : ['neutral']
# your customers want secure reliable multicloud experience can you deliver it to them join our webinar to learn https co cvieh14p6h : ['negative']
# mindshare uk and ibm_uk_news are ad tech london tomorrow in the agency lounge please come by to hear more abo https co 0pae4jmpdx : ['neutral']
#  ibm and škoda auto university collaborate on new digital skills for students https co w5ulocqlcz ai bigdata : ['neutral']
#  opensource collaboration between ibm and redhat is not new one https co 5fh74ascv1 : ['neutral']
# new tutorial monitoring your apps in kubernetes with prometheus and spring boot k8s https co paytzzts49 : ['neutral']
# how blockchain technology amplifies mining industry efficiency https co adepnf9rw3 https co ejmqe7x0hm : ['neutral']
#  okolie_ibm you are just fool displaying stupidity : ['negative']
#  okolie_ibm will it pain me you are nobody goan die  : ['negative']
# when you choose noble1 ithardwaresupport solution you have access to top level support for equipment models from https co 7n59ofiali : ['negative']
#  onomeonyinye the only thing irrelevant is your ability to think properly fix that first : ['negative']
#  onomeonyinye pain am so calling me senseless and sadist was releveant : ['negative']
#  ibm guide pup in training jackie enjoyed showing her smart collar to dog lover senthomtillis we are proud to https co evflukch84 : ['neutral']
# ibm blockchain platform meets red hat openshift https co baxls72ebu https co 7sb9w9uu4u : ['neutral']
# we are very proudly welcoming another sponsor to the techleaders19 leaders awards 2019 thank you to ibm who are https co uoyy6mivkj : ['positive']
#  oyesdaf4life _zieofficial it says joined may 2011 https co epuuregdum : ['neutral']
# ibm drawings titled version plate page 49 from viaggio in italia frank bacher gelatin silver print printed in color : ['negative']
# yes ibm watson is cool but have you met alexa the smarter you work the luckier you get gotalexa getrdone frictionless intelligence  : ['negative']
#  okolie_ibm irrelevant you are sick in the brain  : ['negative']
#  lazygamereviews do you have any ibm pc jr joysticks https co ffs3mjaa3s : ['neutral']
# analytics attribute many to many entities with foreign key relationship resolutions of softwear remy hair dm https co cjchuxskor : ['neutral']
# learn more about the ibm platform and how businesses can run their core applications on practically autonomous https co aaoiqqvoba : ['neutral']
#  rich160160 lauradryad scottfantasy aoc oh really gm still just getting started how about delta chevron hali https co xbezm6ynip : ['negative']
# look back think black racism corporate secrets and two generations of trailblazers at ibm bainbridge island https co rp0svyb581 : ['neutral']
#  onomeonyinye says someone who relies on ugwu leave on her head to be called pretty : ['negative']
# fantasy football insights with watson scours millions of unstructured data sources like news feeds and fan chatter https co 5cdvj3k9i3 : ['neutral']
# ibm watson health celebrates worldpharmacistsday and we are proud of the role that ibm micromedex plays in suppor https co vjxkftaerg : ['neutral']
#  amzn rare green moment for the retail monopoly the other tech bigs are doing well too msft aapl googl nflx https co ca0studfyy : ['neutral']
# ibm 59y4002 intel xeon dp quad core e5507 226ghz 1mb l2 cache 4mb l3 cache 48gt qpi speed 45nm 80w socket fclga 1 https co 3nqw5oopoh : ['neutral']
# moms are magic and ibm knows it https co hw7ksiywb4 : ['neutral']
# how does netflix continue to produce amazing content like stranger_things by leveraging its own data to determi https co nv5eqqn4ei : ['positive']
# really delighted to be involved in ibm think this way this year in such auspicious company blog post on the event https co iuszawnwpf : ['negative']
# hey devs let discuss on which machine did you write your first line of code here a little throwback https co gyylz8q5zf : ['negative']
# the lenovo thinksystem sr950 is their flagship with no hot swap o in 8 socket 12tb know 950 from https co gpobjciyx2 : ['neutral']
#  sap is fanatical about performance how ibm is delivering pmem is the right way to do this there is no performanc https co ezshs7yvka : ['neutral']
# slack users join our community and chat with ibm redbooks staff and readers workspace url https co fxgbbxes0v : ['neutral']
# cindy compert from ibm speaking on ready for ccpa notes that gartner has stated that organisations that are mindf https co uerw5y5t8y : ['neutral']
# some takeaways from our chat with ann rubin of ibm at the brand_innovator bisummit it important to be more https co js0c8aeypq : ['neutral']
# get faster access to the z15 platform enhancements with predictable payments that match your milestones https co yyswn6w451 : ['neutral']
# wooo our team ibm watson studio won an award for our product check it out lt 3 https co km2brjdljx : ['neutral']
# infographic 80 of support issues for opensource software support stem from lack of product knowledge or environm https co 0pyqmb9gpe : ['negative']
# learn how ibm services helps clients secure cloud transformations and provides globally integrated sdn solution https co svghudimgn : ['neutral']
# know in depth about global blockchain in digital marketing market 2019 2026 profiling key players like ibm aws mi https co be4xukpk3q : ['neutral']
# ibm multicloud manager is kubernetes management platform built with security flexibility and an open architectu https co s2eh2n1e1n : ['neutral']
# ibm tririga attains fedramp authorization for software as service internet of things blog https co 97k3v98ita : ['negative']
# data driven content strategy rules for media companies https co qopoakwqlq : ['neutral']
# ibm z15 delivers encryption everywhere to protect you and your ecosystem cloud native development to simplify lif https co kyya2t1fst : ['neutral']
# we are thrilled to welcome technology leaders bernardmarr sallyeaves neilcattermull and dt at thinklondon on https co rwmiqdh0kj : ['neutral']
# read about the opportunity for women to not only contribute to artificialintelligence ai but help lead in its https co y5cqqcc48i : ['neutral']
# sdn is designed to address networking needs that are poorly addressed by existing networks what factors would you https co 9iqblgeem4 : ['neutral']
# jobs qatar ibm mobile first developer qatar michael page https co qtfgysaj7n : ['neutral']
# reinventing clinical trials delivering on the vision of digital transformation in health ibm united kingdom bl https co 9fk9llcusw : ['neutral']
# this series presents the curated development tools amp runtimes of the ibm cloud pak for applications which is built https co tb043dyrd3 : ['neutral']
# airbus obtains greater visibility for facility management with ibm tririga software https co pyuem4b11h : ['neutral']
# ibm systems lab services offers infrastructure services to help you build the foundation for smart enterprise https co wj1904ifpz : ['negative']
#  tessthebutler nova_bushido ibm_uk_news no women are not as interested not debating the rest of your tweet bu https co ugkfmbz4pu : ['neutral']
# these creative leaders from ibm unilever and knotchinc use data to build trust and enhance their companies bra https co xpneb56sfy : ['neutral']
# hey ve just discovered how ibm is helping to improve lives and communities in africa by putting smart to work https co gkyrxdvbte : ['neutral']
# we continue to listen to our clients and design offerings to align with business objectives and it doesn go unn https co du52n9mnxn : ['neutral']
# every day ibm clients in more than 170 countries depend on the secure movement of data across borders we applaud https co mbjgrbj8ku : ['neutral']
#  ibm_uk_news giving more girls more career options is the only positive way know to reduce the human population https co g6jbdwoxu6 : ['negative']
